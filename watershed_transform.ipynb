# %% [markdown]
# # The Segmentation Problem

# %% [markdown]
# # Basins and Regions

# %% [markdown]
# # Local Minima and Gradient Descent

# %% [markdown]
# # The Watershed Transform

# %% [markdown]
# # Testing

# %%
from scipy import misc
test_image = misc.imread('watershed_test_image.jpg', flatten=True)

# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(test_image)
plt.show()

# %%
print test_image[0][0]
# Out:
# 155.811

# %% [markdown]
# # Improvements
